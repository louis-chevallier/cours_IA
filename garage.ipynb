# %% [markdown]
# # Garer une voiture
# - plan = image
# - zone colorié en jaune = cible ( épreuve terminée quand la voiture est completement dessus<br>
# reward = $-$ longueur de la trajectoire
# - zone coloriée en noir : les murs à ne pas toucher : contact => fin<br>
# reward -100
# - zone en rouge : zone de départ possible de la voiture
