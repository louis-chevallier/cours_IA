# %%
# %pwd 
# !pip install gdown
# !pip install utillc
# !pip install xgboost
# %mkdir -p data
# %cd /content/data

# %%
# !gdown --fuzzy https://drive.google.com/file/d/12LjG4Kfv5lmoMHbOuG9PF2Ba5u2SXH_6/view?usp=sharing
# !unzip home_insurance.zip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
from utillc import *
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
# Out:
# without qt5
# no qt5
